# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('./data/Stammdaten_Verkehrsdetektion_2022_07_20.xlsx')

# %%
y2, x2 = 52.51361000, 13.41883000 # Berlin Mitte
coordinates = df[['x', 'y', 'DET_ID15']]
unique_coordinates = coordinates.drop_duplicates(subset=['x', 'y'])
lower_bound = (52.400149, 13.066275)
upper_bound = (52.644374, 13.793748)
np.random.seed(9)
a = np.array(unique_coordinates)
np.random.shuffle(a)

used_traffic_station_list = []




for i, coor in enumerate(a):
    if i > 82:
        break
    used_traffic_station_list.append(int(coor[2]))
    print(coor[1], ',', coor[0], ',', int(coor[2]), ',', '#0000FF')
unique_coordinates
# Out:
# 52.505503 , 13.36333619 , 100101010023712 , #0000FF
# 52.53473797 , 13.27843124 , 100101010016739 , #0000FF
# 52.51144335 , 13.3733365 , 100101010053822 , #0000FF
# 52.52062324 , 13.27995105 , 100101010035230 , #0000FF
# 52.53131551 , 13.29557448 , 100101010043516 , #0000FF
# 52.56605457 , 13.5122723 , 100101010055640 , #0000FF
# 52.48056663 , 13.34652074 , 100101010095046 , #0000FF
# 52.45854208 , 13.47857886 , 100101010054832 , #0000FF
# 52.44813757 , 13.43571359 , 100101010019163 , #0000FF
# 52.45207024 , 13.41966228 , 100101010003504 , #0000FF
# 52.50401729 , 13.3666166 , 100101010058367 , #0000FF
# 52.56719919 , 13.32917518 , 100101010013709 , #0000FF
# 52.48328162 , 13.2918667 , 100101010017547 , #0000FF
# 52.53957747 , 13.36507758 , 100101010061603 , #0000FF
# 52.46383059 , 13.31804085 , 100101010069077 , #0000FF
# 52.56687425 , 13.32908423 , 100101010013507 , #0000FF
# 52.48843966 , 13.33104097 , 100101010041900 , #0000FF
# ...

# %%
print(used_traffic_station_list)
# Out:
# [100101010023712, 100101010016739, 100101010053822, 100101010035230, 100101010043516, 100101010055640, 100101010095046, 100101010054832, 100101010019163, 100101010003504, 100101010058367, 100101010013709, 100101010017547, 100101010061603, 100101010069077, 100101010013507, 100101010041900, 100101010081104, 100101010023914, 100101010069380, 100101010044324, 100101010041088, 100101010022092, 100101010078979, 100101010014113, 100101010011685, 100101010076555, 100101010004110, 100101010017951, 100101010079484, 100101010053620, 100101010066047, 100101010072717, 100101010019870, 100101010032200, 100101010099894, 100101010056448, 100101010053923, 100101010023207, 100101010062007, 100101010065138, 100101010011887, 100101010063017, 100101010086053, 100101010066855, 100101010030681, 100101010064633, 100101010093632, 100101010033311, 100101010062613, 100101010015426, 100101010039977, 100101010020274, 100101010028459, 100101010033513, 100101010022496, 100101010091309, 100101010052812, 10010101003
# ...
