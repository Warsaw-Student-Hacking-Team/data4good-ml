# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('./data/Stammdaten_Verkehrsdetektion_2022_07_20.xlsx')

# %%
x1 = df['x']
y1 = df['y']
y2, x2 = 52.51361000, 13.41883000 # Berlin Mitte
coordinates = df[['x', 'y']]
unique_coordinates = coordinates.drop_duplicates()
# lower_bound = (52.400149, 13.066275)
# upper_bound = (52.644374, 13.793748)
# filtered_coordinates = unique_coordinates[
#     (unique_coordinates['y'] > lower_bound[0]) & (unique_coordinates['y'] < upper_bound[0]) &
#     (unique_coordinates['x'] > lower_bound[1]) & (unique_coordinates['x'] < upper_bound[1])
# ]
for i, coor in enumerate(np.array(unique_coordinates)):
    print(coor[1], ',', coor[0], ',', i, ',', '#0000FF')
# Out:
# 52.43386833 , 13.19257786 , 0 , #0000FF
# 52.43381256 , 13.1927467 , 1 , #0000FF
# 52.43664151 , 13.26130077 , 2 , #0000FF
# 52.43511242 , 13.26310552 , 3 , #0000FF
# 52.43374142 , 13.25988057 , 4 , #0000FF
# 52.43614059 , 13.37926717 , 5 , #0000FF
# 52.41487617 , 13.36441331 , 6 , #0000FF
# 52.40959836 , 13.35974087 , 7 , #0000FF
# 52.41615714 , 13.4000522 , 8 , #0000FF
# 52.41316159 , 13.40209827 , 9 , #0000FF
# 52.43746263 , 13.38824115 , 10 , #0000FF
# 52.42469401 , 13.48488437 , 11 , #0000FF
# 52.42470935 , 13.48491532 , 12 , #0000FF
# 52.4510216 , 13.45291236 , 13 , #0000FF
# 52.45218494 , 13.41975725 , 14 , #0000FF
# 52.45207024 , 13.41966228 , 15 , #0000FF
# 52.57670433 , 13.34798158 , 16 , #0000FF
# 52.57754524 , 13.34778595 , 17 , #0000FF
# 52.57461381 , 13.42952123 , 18 , #0000FF
# 52.42771718 , 13.55284911 , 19 , #0000FF
# 52.55159764 , 13.35380019 , 20 , #0000FF
# 52.55609639 , 13.3632052 , 21 , #0000FF
# 52.55081273 , 13.35147834 , 22 , #0000FF
# ...
